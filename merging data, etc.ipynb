# %%
import pandas as pd

# %%
surveys_df = pd.read_csv('surveys.csv')
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
species_df = pd.read_csv("species.csv")
species_df
# Out:
#    species_id             genus          species     taxa
# 0          AB        Amphispiza        bilineata     Bird
# 1          AH  Ammospermophilus          harrisi   Rodent
# 2          AS        Ammodramus       savannarum     Bird
# 3          BA           Baiomys          taylori   Rodent
# 4          CB   Campylorhynchus  brunneicapillus     Bird
# 5          CM       Calamospiza      melanocorys     Bird
# 6          CQ        Callipepla         squamata     Bird
# 7          CS          Crotalus       scutalatus  Reptile
# 8          CT     Cnemidophorus           tigris  Reptile
# 9          CU     Cnemidophorus        uniparens  Reptile
# 10         CV          Crotalus          viridis  Reptile
# 11         DM         Dipodomys         merriami   Rodent
# 12         DO         Dipodomys            ordii   Rodent
# 13         DS         Dipodomys      spectabilis   Rodent
# 14         DX         Dipodomys              sp.   Rodent
# ...

# %%
surveySub = surveys_df.head(10)

# %%
vertical_stack = pd.concat([surveySub, surveySublast], axis=0)
vertical_stack
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL    M             32.0
# 1          2      7   16  1977        3         NL    M             33.0
# 2          3      7   16  1977        2         DM    F             37.0
# 3          4      7   16  1977        7         DM    M             36.0
# 4          5      7   16  1977        3         DM    M             35.0
# 5          6      7   16  1977        1         PF    M             14.0
# 6          7      7   16  1977        2         PE    F              NaN
# 7          8      7   16  1977        1         DM    M             37.0
# 8          9      7   16  1977        1         DM    F             34.0
# 9         10      7   16  1977        6         PF    F             20.0
# 0      35540     12   31  2002       15         PB    F             26.0
# 1      35541     12   31  2002       15         PB    F             24.0
# ...

# %%
vertical_stack.to_csv("out.csv")

# %%
surveys_1980 = surveys_df[surveys_df.year == 1980]

surveys_1982 = surveys_df[surveys_df.year == 1982]

years_stack = pd.concat([surveys_1980, surveys_1982], axis=0).reset_index()
years_stack

#years_stack.to_csv("years80_82.csv")
# Out:
#       index  record_id  month  day  year  plot_id species_id sex  \
# 0      2270       2271      1   15  1980        8         DO   M
# 1      2271       2272      1   15  1980       11         PF   F
# 2      2272       2273      1   15  1980       18         DM   F
# 3      2273       2274      1   15  1980       11         DM   M
# 4      2274       2275      1   15  1980        8         DO   F
# 5      2275       2276      1   15  1980       11         DS   M
# 6      2276       2277      1   15  1980        8         PF   M
# 7      2277       2278      1   15  1980        9         OT   M
# 8      2278       2279      1   15  1980       11         DM   F
# 9      2279       2280      1   15  1980       21         OT   F
# 10     2280       2281      1   15  1980       11         OL   M
# 11     2281       2282      1   15  1980       17         DM   F
# 12     2282       2283      1   15  1980       11         OL   M
# ...

# %%
surveySub = surveys_df.head(10)
surveySub
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
surveySub
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
species_df.columns
# Out:
# Index([u'species_id', u'genus', u'species', u'taxa'], dtype='object')

# %%
surveySub['species_id']
# Out:
# 0    NL
# 1    NL
# 2    DM
# 3    DM
# 4    DM
# 5    PF
# 6    PE
# 7    DM
# 8    DM
# 9    PF
# Name: species_id, dtype: object

# %%
merged_inner = pd.merge(left="surveySub", 
                        right="species_df", 
                        left_on="species_id",
                        right_on="species_id")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-e4702c1d8559> in <module>()
#       2                         right="species_df",
#       3                         left_on="species_id",
# ----> 4                         right_on="species_id")
#
# /Users/mariastrangas/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      32                          right_on=right_on, left_index=left_index,
#      33                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 34                          copy=copy, indicator=indicator)
#      35     return op.get_result()
#      36 if __debug__:
#
# ...
