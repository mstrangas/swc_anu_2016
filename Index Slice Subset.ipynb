# %%
import pandas as pd

# %%
surveys_df = pd.read_csv('surveys.csv')

# %%
surveys_df[['species_id', 'plot_id']].head()
# Out:
#   species_id  plot_id
# 0         NL        2
# 1         NL        3
# 2         DM        2
# 3         DM        7
# 4         DM        3

# %%
nums = [1,2,3,4,5]

# %%
surveys_df.iloc[0:3,1:4]

# %%
surveys_df.loc[0:3,:]

# %%
surveys_df.iloc[0:3,:]

# %%
type(surveys_df.loc[[0,10,400000],])
# Out:
# pandas.core.frame.DataFrame

# %%
type(surveys_df.iloc[2,6])
# Out:
# str

# %%
surveys_df[surveys_df.year != 2002].head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df[(surveys_df.year >= 1980)& (surveys_df.year <= 1985)].head()
# Out:
#       record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 2270       2271      1   15  1980        8         DO   M             35.0
# 2271       2272      1   15  1980       11         PF   F             16.0
# 2272       2273      1   15  1980       18         DM   F             34.0
# 2273       2274      1   15  1980       11         DM   M             38.0
# 2274       2275      1   15  1980        8         DO   F             33.0
#
#       weight
# 2270    53.0
# 2271    10.0
# 2272    33.0
# 2273    37.0
# 2274    29.0

# %%
surveys_df[(surveys_df.year == 1999)& (surveys_df.weight <= 8)]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 29082      29083      1   16  1999       21         RM   M             16.0
# 29196      29197      2   20  1999       18         RM   M             18.0
# 29421      29422      3   15  1999       16         RM   M             15.0
# 29903      29904     10   10  1999        4         PP   M             20.0
# 29905      29906     10   10  1999        4         PP   M             21.0
#
#        weight
# 29082     8.0
# 29196     8.0
# 29421     8.0
# 29903     7.0
# 29905     4.0

# %%
surveys_df[surveys_df['species_id'].isin(["RM", "PP"])].count()
# Out:
# record_id          5732
# month              5732
# day                5732
# year               5732
# plot_id            5732
# species_id         5732
# sex                5624
# hindfoot_length    5469
# weight             5559
# dtype: int64

# %%
surveys_df[(surveys_df.weight >= 0)].count()
# Out:
# record_id          32283
# month              32283
# day                32283
# year               32283
# plot_id            32283
# species_id         32283
# sex                32182
# hindfoot_length    30738
# weight             32283
# dtype: int64

# %%
surveys_df[surveys_df['sex'].isin(["M", "F"])].count()
# Out:
# record_id          33038
# month              33038
# day                33038
# year               33038
# plot_id            33038
# species_id         33038
# sex                33038
# hindfoot_length    31370
# weight             32182
# dtype: int64

# %%
surveys_df[(surveys_df['sex']==("M")) ]

# %%
surveys_df[(surveys_df['sex']==("F"))]

# %%
surveys_df[~(surveys_df['sex'].isin(["M", "F"]))].head()
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 13         14      7   16  1977        8         DM  NaN              NaN
# 18         19      7   16  1977        4         PF  NaN              NaN
# 33         34      7   17  1977       17         DM  NaN              NaN
# 56         57      7   18  1977       22         DM  NaN              NaN
# 76         77      8   19  1977        4         SS  NaN              NaN
#
#     weight
# 13     NaN
# 18     NaN
# 33     NaN
# 56     NaN
# 76     NaN

# %%
surveys_df[(surveys_df.year >= 1980) 
          & (surveys_df.year <= 1985)
          & ~(surveys_df["species_id"].isnull())
          ].head()
# Out:
#       record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 2270       2271      1   15  1980        8         DO   M             35.0
# 2271       2272      1   15  1980       11         PF   F             16.0
# 2272       2273      1   15  1980       18         DM   F             34.0
# 2273       2274      1   15  1980       11         DM   M             38.0
# 2274       2275      1   15  1980        8         DO   F             33.0
#
#       weight
# 2270    53.0
# 2271    10.0
# 2272    33.0
# 2273    37.0
# 2274    29.0

# %%
surveys_df[(surveys_df.year >= 1980) 
          & (surveys_df.year <= 1985)
          & (surveys_df["species_id"]=='NaN')
          ].head()
# Out:
# Empty DataFrame
# Columns: [record_id, month, day, year, plot_id, species_id, sex, hindfoot_length, weight]
# Index: []

# %%
~(surveys_df["species_id"].isnull())
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 35519     True
# 35520     True
# 35521     True
# 35522     True
# 35523     True
# 35524     True
# 35525     True
# 35526     True
# 35527     True
# 35528     True
# 35529     True
# 35530     True
# 35531     True
# 35532     True
# 35533     True
# 35534     True
# 35535     True
# 35536     True
# 35537     True
# 35538     True
# 35539     True
# 35540     True
# 35541     True
# 35542     True
# 35543     True
# 35544     True
# 35545     True
# ...

# %%
pd.isnull(surveys_df).head()
# Out:
#   record_id  month    day   year plot_id species_id    sex hindfoot_length  \
# 0     False  False  False  False   False      False  False           False
# 1     False  False  False  False   False      False  False           False
# 2     False  False  False  False   False      False  False           False
# 3     False  False  False  False   False      False  False           False
# 4     False  False  False  False   False      False  False           False
#
#   weight
# 0   True
# 1   True
# 2   True
# 3   True
# 4   True

# %%
surveys_df.isnull()
# Out:
#       record_id  month    day   year plot_id species_id    sex  \
# 0         False  False  False  False   False      False  False
# 1         False  False  False  False   False      False  False
# 2         False  False  False  False   False      False  False
# 3         False  False  False  False   False      False  False
# 4         False  False  False  False   False      False  False
# 5         False  False  False  False   False      False  False
# 6         False  False  False  False   False      False  False
# 7         False  False  False  False   False      False  False
# 8         False  False  False  False   False      False  False
# 9         False  False  False  False   False      False  False
# 10        False  False  False  False   False      False  False
# 11        False  False  False  False   False      False  False
# 12        False  False  False  False   False      False  False
# 13        False  False  False  False   False      False   True
# ...

# %%
surveys_df[pd.isnull(surveys_df).any(axis=1)]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
surveys_df[~(pd.isnull(surveys_df).any(axis=1))]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 62            63      8   19  1977        3         DM   M             35.0
# 63            64      8   19  1977        7         DM   M             37.0
# 64            65      8   19  1977        4         DM   F             34.0
# 65            66      8   19  1977        4         DM   F             35.0
# 66            67      8   19  1977        7         DM   M             35.0
# 67            68      8   19  1977        8         DO   F             32.0
# 68            69      8   19  1977        2         PF   M             15.0
# 69            70      8   19  1977        3         OX   F             21.0
# 70            71      8   19  1977        7         DM   F             36.0
# 73            74      8   19  1977        8         PF   M             12.0
# 74            75      8   19  1977        8         DM   F             32.0
# ...

# %%
surveys_noMF =surveys_df[~(surveys_df['sex'].isin(["M", "F"]))]
surveys_noMF.head()
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 13         14      7   16  1977        8         DM  NaN              NaN
# 18         19      7   16  1977        4         PF  NaN              NaN
# 33         34      7   17  1977       17         DM  NaN              NaN
# 56         57      7   18  1977       22         DM  NaN              NaN
# 76         77      8   19  1977        4         SS  NaN              NaN
#
#     weight
# 13     NaN
# 18     NaN
# 33     NaN
# 56     NaN
# 76     NaN

# %%
surveys_noMF.loc[:,["sex"]]='x'
surveys_noMF.head()
# Out:
#     record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 13         14      7   16  1977        8         DM   x              NaN
# 18         19      7   16  1977        4         PF   x              NaN
# 33         34      7   17  1977       17         DM   x              NaN
# 56         57      7   18  1977       22         DM   x              NaN
# 76         77      8   19  1977        4         SS   x              NaN
#
#     weight
# 13     NaN
# 18     NaN
# 33     NaN
# 56     NaN
# 76     NaN

# %%
surveys_ok =surveys_df[(surveys_df['sex'].isin(["M", "F"]))
                        & (surveys_df.weight >= 0)]

surveys_ok.head()
# Out:
#     record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 62         63      8   19  1977        3         DM   M             35.0
# 63         64      8   19  1977        7         DM   M             37.0
# 64         65      8   19  1977        4         DM   F             34.0
# 65         66      8   19  1977        4         DM   F             35.0
# 66         67      8   19  1977        7         DM   M             35.0
#
#     weight
# 62    40.0
# 63    48.0
# 64    29.0
# 65    46.0
# 66    36.0

# %%
# %matplotlib inline
# Out:
# /Users/mariastrangas/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
surveys_ok.plot(kind="bar")
